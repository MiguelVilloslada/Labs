# %% [markdown]
# __Miguel's Jupyter Notebook__

# %% [markdown]
# *The purpose of the notebook is to get used to Jupyter notebook*

# %%
name = input('What is your name?')
#user is asked about his/her name
# Out:
# What is your name?Miguel Angel

# %%
print('My name is',name)
# Out:
# My name is Miguel Angel

# %%
holiday = input('What is your favorite holiday?')
# Out:
# What is your favorite holiday?summer

# %% [markdown]
# ![pic_from_web.png](data:image/jpeg;base64,...)

# %%
Preference = input('What do you like to do in the summer?')
# Out:
# What do you like to do in the summer?surfing

# %% [markdown]
# - surfing
# - sunbath
# - diving

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('_azIoZ50zuM', width=400, height=200)
